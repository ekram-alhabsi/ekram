# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Replace 'Housing.csv' with the actual uploaded filename
dataTrain = pd.read_csv(io.BytesIO(uploaded['Housing.csv']))
dataTrain.head()
# Out:
#      <input type="file" id="files-be5cfa34-f8de-4145-ad74-dcae3cbfb864" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be5cfa34-f8de-4145-ad74-dcae3cbfb864">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
type(dataTrain)
# Out:
# pandas.core.frame.DataFrame

# %%
dataTrain.shape
# Out:
# (545, 13)

# %%
dataTrain.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
dataTrain[dataTrain.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []

# %%
dataTrain = dataTrain.dropna()

# %%
dataTrain.isnull().sum()
# Out:
# Channel Name                   0
# Youtuber Name                  0
# Total Videos                   0
# Best Video                     0
# Avg Video Length (min)         0
# Total Subscribers              0
# Members Count                  0
# AI Generated Content (%)       0
# Neural Interface Compatible    0
# Metaverse Integration Level    0
# Quantum Computing Topics       0
# Holographic Content Rating     0
# Engagement Score               0
# Content Value Index            0
# dtype: int64

# %%
dataTrain.shape
# Out:
# (545, 13)

# %%
dataTrain.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# %time
corr = dataTrain.select_dtypes(include=['number']).corr()

sns.heatmap(corr, annot=True, xticklabels=corr.columns, yticklabels=corr.columns)
plt.show()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.72 µs

# %%
# !pip install fireducks
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 16.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

dataTrain_fd = pd.read_csv('/content/drive/MyDrive/house_estimation/housing.csv')
dataTrain_fd = dataTrain_fd.dropna()

# %time
corr = dataTrain_fd.select_dtypes(include=['number']).corr()

sns.heatmap(corr, annot=True, xticklabels=corr.columns, yticklabels=corr.columns)

plt.show()
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 32.4 µs

# %%
dataTrain.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
import pandas as pd

# Step 1: Load the dataset
dataTrain = pd.read_csv('/content/drive/MyDrive/house_estimation/housing.csv')  # Replace with correct path if needed

# Step 2: Replace '1' with '500' in 'price'
dataTrain.loc[dataTrain['price'] == 1, 'price'] = 500

# %%
dataTrain.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
dataTrain.loc[dataTrain['price'] < 500, 'price'] = 500

# %%
dataTrain.describe()
# Out:
#        Total Videos  Avg Video Length (min)  Total Subscribers  Members Count  \
# count    5000.00000             5000.000000       5.000000e+03     5000.00000
# mean      274.43340               24.004540       5.058482e+06   249082.01980
# std       131.71675                0.874555       2.890895e+06   143555.47327
# min        50.00000               19.100000       1.755000e+03      143.00000
# 25%       159.00000               23.500000       2.547991e+06   127000.75000
# 50%       274.00000               24.000000       5.105967e+06   252320.50000
# 75%       389.00000               24.500000       7.541903e+06   371419.25000
# max       500.00000               28.900000       9.999975e+06   499991.00000
#
#        AI Generated Content (%)  Quantum Computing Topics  Engagement Score  \
# count               5000.000000               5000.000000       5000.000000
# mean                  49.328600                 10.061400      79974.100470
# ...

# %%
import matplotlib.pyplot as plt

dataTrain['price'].plot(kind='hist', bins=5, edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of House Prices')
plt.show()

# %%
dataTrain.describe(include = 'object') #summary statistics for categorical values
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.regplot(x="area", y="price", data=dataTrain)
plt.title("Regression Plot: Area vs Price")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.show()

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(dataTrain['area'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5359973457780801 with a P-value of P = 7.388225401521693e-42

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.regplot(x="area", y="price", data=dataTrain)
plt.title("Regression Plot: Area vs Price")
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.show()

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(dataTrain['area'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5359973457780801 with a P-value of P = 7.388225401521693e-42

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.regplot(x="bedrooms", y="price", data=dataTrain)
plt.title("Regression Plot: Bedrooms vs Price")
plt.xlabel("Number of Bedrooms")
plt.ylabel("House Price")
plt.show()

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(dataTrain['bedrooms'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.3664940257738684 with a P-value of P = 9.080301855811535e-19

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.regplot(x="stories", y="price", data=dataTrain)
plt.title("Regression Plot: Stories vs Price")
plt.xlabel("Number of Stories")
plt.ylabel("House Price")
plt.show()

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(dataTrain['bathrooms'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5175453394550111 with a P-value of P = 1.1393218375126212e-38

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.regplot(x="parking", y="price", data=dataTrain)
plt.title("Regression Plot: Parking vs Price")
plt.xlabel("Number of Parking Spaces")
plt.ylabel("House Price")
plt.show()

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(dataTrain['parking'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.3843936486357264  with a P-value of P = 1.2383784426341963e-20

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.regplot(x="area", y="price", data=dataTrain)
plt.title("Regression Plot: Area vs Price")
plt.xlabel("Area (sq ft)")
plt.ylabel("House Price")
plt.show()

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(dataTrain['area'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5359973457780801  with a P-value of P = 7.388225401521693e-42

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="furnishingstatus", y="price", data=dataTrain)
plt.title("Boxplot: Furnishing Status vs House Price")
plt.xlabel("Furnishing Status")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="mainroad", y="price", data=dataTrain)
plt.title("Boxplot: Main Road Access vs House Price")
plt.xlabel("Main Road Access")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="basement", y="price", data=dataTrain)
plt.title("Boxplot: Basement Availability vs House Price")
plt.xlabel("Basement")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="guestroom", y="price", data=dataTrain)
plt.title("Boxplot: Guest Room Availability vs House Price")
plt.xlabel("Guest Room")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="airconditioning", y="price", data=dataTrain)
plt.title("Boxplot: Air Conditioning vs House Price")
plt.xlabel("Air Conditioning")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="hotwaterheating", y="price", data=dataTrain)
plt.title("Boxplot: Hot Water Heating vs House Price")
plt.xlabel("Hot Water Heating")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="prefarea", y="price", data=dataTrain)
plt.title("Boxplot: Preferred Area vs House Price")
plt.xlabel("Preferred Area")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=dataTrain['stories'].astype(str), y="price", data=dataTrain)
plt.title("Boxplot: Number of Stories vs House Price")
plt.xlabel("Stories")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=dataTrain['parking'].astype(str), y="price", data=dataTrain)
plt.title("Boxplot: Parking Spaces vs House Price")
plt.xlabel("Parking")
plt.ylabel("House Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=dataTrain['bathrooms'].astype(str), y="price", data=dataTrain)
plt.title("Boxplot: Bathrooms vs House Price")
plt.xlabel("Bathrooms")
plt.ylabel("House Price")
plt.show()

# %%
dataTrain.drop(['furnishingstatus'], axis=1, inplace=True)

# %%
dataTrain.shape
# Out:
# (545, 12)

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()

# Safe encoding for all valid categorical columns
for col in ['mainroad', 'guestroom', 'basement', 'hotwaterheating',
            'airconditioning', 'prefarea', 'furnishingstatus']:
    if col in dataTrain.columns:
        dataTrain[col] = labelencoder.fit_transform(dataTrain[col])

# %%
dataTrain.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000   7420         4          2        3         1          0
# 1  12250000   8960         4          4        4         1          0
# 2  12250000   9960         3          2        2         1          0
# 3  12215000   7500         4          2        2         1          0
# 4  11410000   7420         4          1        2         1          1
# 5  10850000   7500         3          3        1         1          0
# 6  10150000   8580         4          3        4         1          0
# 7  10150000  16200         5          3        2         1          0
# 8   9870000   8100         4          1        2         1          1
# 9   9800000   5750         3          2        4         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dataTrain = scaler.fit_transform(dataTrain)

# %%
dataTrain
# Out:
# array([[1.        , 0.39656357, 0.6       , ..., 1.        , 0.66666667,
#         1.        ],
#        [0.90909091, 0.5024055 , 0.6       , ..., 1.        , 1.        ,
#         0.        ],
#        [0.90909091, 0.57113402, 0.4       , ..., 0.        , 0.66666667,
#         1.        ],
#        ...,
#        [0.        , 0.13539519, 0.2       , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.08659794, 0.4       , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.15120275, 0.4       , ..., 0.        , 0.        ,
#         0.        ]])

# %%
import pandas as pd

dataTrain = pd.read_csv('Housing.csv')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
dataTrain_scaled = scaler.fit_transform(dataTrain)

# %%
x_train = dataTrain.drop('price', axis=1)
y_train = dataTrain[['price']]

# %%
from sklearn.model_selection import train_test_split

# Split the data: 70% for training, 30% for testing
x_train, x_test, y_train, y_test = train_test_split(
    x_train, y_train, test_size=0.3, random_state=0
)

# %%
x_train.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 454  0.195876       0.4        0.0  0.333333       1.0        0.0       0.0
# 392  0.160825       0.4        0.0  0.333333       1.0        0.0       0.0
# 231  0.183505       0.4        0.0  0.000000       1.0        0.0       0.0
# 271  0.017526       0.8        0.0  0.333333       0.0        0.0       1.0
# 250  0.127835       0.4        0.0  0.666667       1.0        0.0       0.0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 454              0.0              1.0      0.0       0.0               1.0
# 392              0.0              0.0      0.0       0.0               0.5
# 231              0.0              0.0      0.0       1.0               0.5
# 271              0.0              0.0      0.0       0.0               0.5
# 250              0.0              0.0      0.0       0.0               0.5

# %%
y_train.head()
# Out:
#         price
# 454  0.120606
# 392  0.151515
# 231  0.254545
# 271  0.224242
# 250  0.239394

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (381, 12)
# y_train shape: (381, 1)
# x_test shape: (164, 12)
# y_test shape: (164, 1)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model_mlr = model.fit(x_train, y_train)

# %%
y_pred1 = model_mlr.predict(x_test)

# %%
mse1 = mean_squared_error(y_test, y_pred1)
print('The mean square error for Multiple Linear Regression: ', mse1)
# Out:
# The mean square error for Multiple Linear Regression:  0.007189601984826966

# %%
mae1= mean_absolute_error(y_test, y_pred1)
print('The mean absolute error for Multiple Linear Regression: ', mae1)
# Out:
# The mean absolute error for Multiple Linear Regression:  0.06347638141960302

# %%
rf = RandomForestRegressor()
model_rf = rf.fit(x_train,y_train)

# %%
y_pred2 = model_rf.predict(x_test)

# %%
mse2 = mean_squared_error(y_test, y_pred2)
print('The mean square error of price and predicted value is: ', mse2)
# Out:
# The mean square error of price and predicted value is:  0.009832242528771563

# %%
mae2= mean_absolute_error(y_test, y_pred2)
print('The mean absolute error of price and predicted value is: ', mae2)
# Out:
# The mean absolute error of price and predicted value is:  0.07110116587477562

# %%
mae1 = mean_absolute_error(y_test, y_pred1)
mae2 = mean_absolute_error(y_test, y_pred2)

# %%
mse1 = mean_squared_error(y_test, y_pred1)  # Linear Regression
mse2 = mean_squared_error(y_test, y_pred2)  # Random Forest

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)  # you can tune alpha
lasso_model = lasso.fit(x_train, y_train)
y_pred3 = lasso_model.predict(x_test)

from sklearn.metrics import mean_absolute_error
mae3 = mean_absolute_error(y_test, y_pred3)

# %%
scores = [('MLR', mae1),
          ('Random Forest', mae2),
          ('LASSO', mae3)]

# %%
mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
mae
# Out:
#            Model  MAE Score
# 0            MLR   0.063476
# 1  Random Forest   0.071101
# 2          LASSO   0.124715

# %%
mae.sort_values(by=(['MAE Score']), ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(10,7))
sns.barplot(x = mae['Model'], y=mae['MAE Score'], ax = axe)
axe.set_xlabel('Model', size=20)
axe.set_ylabel('Mean Absolute Error', size=20)

plt.show()

# %% [markdown]
# MLR
